# %%
import networkx as nx
import numpy as np
import copy as cy
import math

def comp_dist(file1,file2):
    G = nx.DiGraph()
    images = []
    files = [file1,file2]
    for i in range(2):
        with open(files[i], "r") as f:
            a = np.zeros((10,80),dtype=int)
            array = []
            for line in f:
                row = list(line.strip())
                array.append(row)
            for i in range(10):
                a[i,] = array[i]
            images.append(a)

    count_bright = 0
    count_zeros = 0

    firstLoc = []
    secondLoc = []
    for i in range(10):
        for k in range(80):
            if images[0][i,k] != 0:
                count_bright += 1
                firstLoc.append([i,k,images[0][i,k],count_bright])
                G.add_node(f"{images[0][i,k]}.{count_bright}", demand = -1* images[0][i,k])
            if (images[0][i,k] == 0):
                count_zeros += 1
                G.add_node(f"{images[0][i,k]}.{count_zeros}", demand = -1* images[0][i,k])
            if (images[1][i,k] != 0):
                count_bright += 1
                secondLoc.append([i,k,images[1][i,k],count_bright])
                G.add_node(f"{images[1][i,k]}.{count_bright}", demand = images[1][i,k])
            if (images[1][i,k] == 0):
                count_zeros += 1
                G.add_node(f"{images[1][i,k]}.{count_zeros}", demand = images[1][i,k])

    for i in range(len(firstLoc)):
        for j in range(len(firstLoc)):
            if ((firstLoc[i][0]*10+firstLoc[i][1])!=(firstLoc[j][0]*10+firstLoc[j][1])):
                if firstLoc[i][1]>firstLoc[j][1]:
                    G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{firstLoc[j][2]}.{firstLoc[j][3]}", weight = 80-(firstLoc[i][1] - firstLoc[j][1]))
                else:
                    G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{firstLoc[j][2]}.{firstLoc[j][3]}", weight = abs(firstLoc[i][1] - firstLoc[j][1]))
        for k in range(len(secondLoc)):
            for l in range(len(secondLoc)):
                if ((secondLoc[k][0]*10+secondLoc[k][1])!=(secondLoc[l][0]*10+secondLoc[l][1])):
                    if secondLoc[k][1]>secondLoc[l][1]:
                        G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{secondLoc[l][2]}.{secondLoc[l][3]}", weight = 80-(secondLoc[k][1] - secondLoc[l][1]))
                    else:
                        G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{secondLoc[l][2]}.{secondLoc[l][3]}", weight =abs(secondLoc[k][1] - secondLoc[l][1])) 

    for i in range(len(firstLoc)):
        for k in range(len(secondLoc)):
            if  firstLoc[i][1] >= secondLoc[k][1]:
                 G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{secondLoc[k][2]}.{secondLoc[k][3]}",weight = 80-(firstLoc[i][1] - secondLoc[k][1]))
            else:
                G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{secondLoc[k][2]}.{secondLoc[k][3]}",weight = abs(firstLoc[i][1] - secondLoc[k][1]))
    for k in range(len(secondLoc)):
        for i in range(len(firstLoc)):
            if  firstLoc[i][1] < secondLoc[k][1]:
                G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{firstLoc[i][2]}.{firstLoc[i][3]}",weight = 80-(secondLoc[k][1] - firstLoc[i][1]))
            else:
                 G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{firstLoc[i][2]}.{firstLoc[i][3]}", weight = abs(firstLoc[i][1] - secondLoc[k][1]))

    return float(nx.algorithms.min_cost_flow_cost(G))
            
def sort_files():
    #files = ['P1.txt', 'P2.txt', 'P3.txt', 'P4.txt', 'P5.txt', 'P6.txt', 'P7.txt', 'P8.txt', 'P9.txt', 'P10.txt', 'P11.txt', 'P12.txt', 'P13.txt', 'P14.txt', 'P15.txt']
    files = ['P1.txt', 'P2.txt', 'P3.txt', 'P4.txt', 'P5.txt', 'P6.txt', 'P7.txt', 'P8.txt', 'P9.txt', 'P11.txt', 'P12.txt', 'P13.txt', 'P14.txt']
    temp = cy.deepcopy(files)
    sorting = [('P1.txt', 1)]
    count = 2
    del temp[0]
    for i in sorting:
        dists = []
        for k in temp:
            if i[0]==k:
                continue
            dists.append((comp_dist(files[files.index(i[0])],files[files.index(k)]),k))   
        print(dists)
        if len(dists) != 0:
            sorting.append((min(dists)[1],count))
            count += 1
            temp.remove(min(dists)[1])
    sorted_files = list(map(lambda x: x[0], sorting))
    return sorted_files
print(sort_files())
print(type(float(comp_dist("P2.txt","P6.txt"))))
# Out:
# [(160.0, 'P2.txt'), (1120.0, 'P3.txt'), (1600.0, 'P4.txt'), (4480.0, 'P5.txt'), (4800.0, 'P6.txt'), (3200.0, 'P7.txt'), (5680.0, 'P8.txt'), (2000.0, 'P9.txt'), (3920.0, 'P11.txt'), (3520.0, 'P12.txt'), (1680.0, 'P13.txt'), (1760.0, 'P14.txt')]
# [(960.0, 'P3.txt'), (1440.0, 'P4.txt'), (4320.0, 'P5.txt'), (4640.0, 'P6.txt'), (3040.0, 'P7.txt'), (5520.0, 'P8.txt'), (1840.0, 'P9.txt'), (3760.0, 'P11.txt'), (3360.0, 'P12.txt'), (1520.0, 'P13.txt'), (1600.0, 'P14.txt')]
# [(480.0, 'P4.txt'), (3360.0, 'P5.txt'), (3680.0, 'P6.txt'), (2080.0, 'P7.txt'), (4560.0, 'P8.txt'), (880.0, 'P9.txt'), (2800.0, 'P11.txt'), (2400.0, 'P12.txt'), (560.0, 'P13.txt'), (640.0, 'P14.txt')]
# [(2880.0, 'P5.txt'), (3200.0, 'P6.txt'), (1600.0, 'P7.txt'), (4080.0, 'P8.txt'), (400.0, 'P9.txt'), (2320.0, 'P11.txt'), (1920.0, 'P12.txt'), (80.0, 'P13.txt'), (160.0, 'P14.txt')]
# ...

# %%
import networkx as nx
import numpy as np
import copy as cy
import math

def comp_dist(file1,file2):
    G = nx.DiGraph()
    images = []
    files = [file1,file2]
    for i in range(2):
        with open(files[i], "r") as f:
            a = np.zeros((10,80),dtype=int)
            array = []
            for line in f:
                row = list(line.strip())
                array.append(row)
            for i in range(10):
                a[i,] = array[i]
            images.append(a)

    count_bright = 0
    count_zeros = 0

    firstLoc = []
    secondLoc = []
    for i in range(10):
        for k in range(80):
            if images[0][i,k] != 0:
                count_bright += 1
                firstLoc.append([i,k,images[0][i,k],count_bright])
                G.add_node(f"{images[0][i,k]}.{count_bright}", demand = -1* images[0][i,k])
            if (images[0][i,k] == 0):
                count_zeros += 1
                #G.add_node(f"{images[0][i,k]}.{count_zeros}", demand = -1* images[0][i,k])
            if (images[1][i,k] != 0):
                count_bright += 1
                secondLoc.append([i,k,images[1][i,k],count_bright])
                G.add_node(f"{images[1][i,k]}.{count_bright}", demand = images[1][i,k])
            if (images[1][i,k] == 0):
                count_zeros += 1
                #G.add_node(f"{images[1][i,k]}.{count_zeros}", demand = images[1][i,k])

    for i in range(len(firstLoc)):
        for j in range(len(firstLoc)):
            if ((firstLoc[i][0]*10+firstLoc[i][1])!=(firstLoc[j][0]*10+firstLoc[j][1])):
                if firstLoc[i][1]>firstLoc[j][1]:
                    G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{firstLoc[j][2]}.{firstLoc[j][3]}", weight = 80-(firstLoc[i][1] - firstLoc[j][1]))
                else:
                    G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{firstLoc[j][2]}.{firstLoc[j][3]}", weight = abs(firstLoc[i][1] - firstLoc[j][1]))
        for k in range(len(secondLoc)):
            for l in range(len(secondLoc)):
                if ((secondLoc[k][0]*10+secondLoc[k][1])!=(secondLoc[l][0]*10+secondLoc[l][1])):
                    if secondLoc[k][1]>secondLoc[l][1]:
                        G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{secondLoc[l][2]}.{secondLoc[l][3]}", weight = 80-(secondLoc[k][1] - secondLoc[l][1]))
                    else:
                        G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{secondLoc[l][2]}.{secondLoc[l][3]}", weight =abs(secondLoc[k][1] - secondLoc[l][1])) 

    for i in range(len(firstLoc)):
        for k in range(len(secondLoc)):
            if  firstLoc[i][1] >= secondLoc[k][1]:
                 G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{secondLoc[k][2]}.{secondLoc[k][3]}",weight = 80-(firstLoc[i][1] - secondLoc[k][1]))
            else:
                G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{secondLoc[k][2]}.{secondLoc[k][3]}",weight = abs(firstLoc[i][1] - secondLoc[k][1]))
    for k in range(len(secondLoc)):
        for i in range(len(firstLoc)):
            if  firstLoc[i][1] < secondLoc[k][1]:
                G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{firstLoc[i][2]}.{firstLoc[i][3]}",weight = 80-(secondLoc[k][1] - firstLoc[i][1]))
            else:
                 G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{firstLoc[i][2]}.{firstLoc[i][3]}", weight = abs(firstLoc[i][1] - secondLoc[k][1]))

    return float(nx.algorithms.min_cost_flow_cost(G))
            
def sort_files():
    #files = ['P1.txt', 'P2.txt', 'P3.txt', 'P4.txt', 'P5.txt', 'P6.txt', 'P7.txt', 'P8.txt', 'P9.txt', 'P10.txt', 'P11.txt', 'P12.txt', 'P13.txt', 'P14.txt', 'P15.txt']
    files = ['P1.txt', 'P2.txt', 'P3.txt', 'P4.txt', 'P5.txt', 'P6.txt', 'P7.txt', 'P8.txt', 'P9.txt', 'P11.txt', 'P12.txt', 'P13.txt', 'P14.txt']
    temp = cy.deepcopy(files)
    sorting = [('P1.txt', 1)]
    count = 2
    del temp[0]
    for i in sorting:
        dists = []
        for k in temp:
            if i[0]==k:
                continue
            dists.append((comp_dist(files[files.index(i[0])],files[files.index(k)]),k))   
        print(dists)
        if len(dists) != 0:
            sorting.append((min(dists)[1],count))
            count += 1
            temp.remove(min(dists)[1])
    sorted_files = list(map(lambda x: x[0], sorting))
    return sorted_files
print(sort_files())
#print(comp_dist("P2.txt","P6.txt"))
# Out:
# [(160.0, 'P2.txt'), (1120.0, 'P3.txt'), (1600.0, 'P4.txt'), (4480.0, 'P5.txt'), (4800.0, 'P6.txt'), (3200.0, 'P7.txt'), (5680.0, 'P8.txt'), (2000.0, 'P9.txt'), (3920.0, 'P11.txt'), (3520.0, 'P12.txt'), (1680.0, 'P13.txt'), (1760.0, 'P14.txt')]
# [(960.0, 'P3.txt'), (1440.0, 'P4.txt'), (4320.0, 'P5.txt'), (4640.0, 'P6.txt'), (3040.0, 'P7.txt'), (5520.0, 'P8.txt'), (1840.0, 'P9.txt'), (3760.0, 'P11.txt'), (3360.0, 'P12.txt'), (1520.0, 'P13.txt'), (1600.0, 'P14.txt')]
# [(480.0, 'P4.txt'), (3360.0, 'P5.txt'), (3680.0, 'P6.txt'), (2080.0, 'P7.txt'), (4560.0, 'P8.txt'), (880.0, 'P9.txt'), (2800.0, 'P11.txt'), (2400.0, 'P12.txt'), (560.0, 'P13.txt'), (640.0, 'P14.txt')]
# [(2880.0, 'P5.txt'), (3200.0, 'P6.txt'), (1600.0, 'P7.txt'), (4080.0, 'P8.txt'), (400.0, 'P9.txt'), (2320.0, 'P11.txt'), (1920.0, 'P12.txt'), (80.0, 'P13.txt'), (160.0, 'P14.txt')]
# ...

# %%
import networkx as nx
import numpy as np
import copy as cy
import math

def comp_dist(file1,file2):
    G = nx.DiGraph()
    images = []
    files = [file1,file2]
    for i in range(2):
        with open(files[i], "r") as f:
            a = np.zeros((10,80),dtype=int)
            array = []
            for line in f:
                row = list(line.strip())
                array.append(row)
            for i in range(10):
                a[i,] = array[i]
            images.append(a)

    count_bright = 0
    count_zeros = 0

    firstLoc = []
    secondLoc = []
    for i in range(10):
        for k in range(80):
            if images[0][i,k] != 0:
                count_bright += 1
                firstLoc.append([i,k,images[0][i,k],count_bright])
                #G.add_node(f"{images[0][i,k]}.{count_bright}", demand = -1* images[0][i,k])
            # if (images[0][i,k] == 0):
            #     count_zeros += 1
                #G.add_node(f"{images[0][i,k]}.{count_zeros}", demand = -1* images[0][i,k])
            if (images[1][i,k] != 0):
                count_bright += 1
                secondLoc.append([i,k,images[1][i,k],count_bright])
                #G.add_node(f"{images[1][i,k]}.{count_bright}", demand = images[1][i,k])
            # if (images[1][i,k] == 0):
                # count_zeros += 1
                #G.add_node(f"{images[1][i,k]}.{count_zeros}", demand = images[1][i,k])
    
    # b = cy.deepcopy(firstLoc)
    # b.extend(secondLoc)
    # c = [brig[2] for brig in b]
    # a = np.lcm(sum(val[2] for val in firstLoc),sum(val2[2] for val2 in secondLoc))
    # print(a)
    
    normalizer = 3120/sum(val[2] for val in firstLoc)
    normalizer2 = 3120/sum(val2[2] for val2 in secondLoc)


    for i in firstLoc:
        G.add_node(f"{i[2]}.{i[3]}", demand = -1* i[2] * abs(normalizer))
    for i in secondLoc:
        G.add_node(f"{i[2]}.{i[3]}", demand = 1* i[2] * abs(normalizer2))


    for i in range(len(firstLoc)):
        for j in range(len(firstLoc)):
            if ((firstLoc[i][0]*10+firstLoc[i][1])!=(firstLoc[j][0]*10+firstLoc[j][1])):
                if firstLoc[i][1]>firstLoc[j][1]:
                    G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{firstLoc[j][2]}.{firstLoc[j][3]}", weight = 80-(firstLoc[i][1] - firstLoc[j][1]))
                else:
                    G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{firstLoc[j][2]}.{firstLoc[j][3]}", weight = abs(firstLoc[i][1] - firstLoc[j][1]))
        for k in range(len(secondLoc)):
            for l in range(len(secondLoc)):
                if ((secondLoc[k][0]*10+secondLoc[k][1])!=(secondLoc[l][0]*10+secondLoc[l][1])):
                    if secondLoc[k][1]>secondLoc[l][1]:
                        G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{secondLoc[l][2]}.{secondLoc[l][3]}", weight = 80-(secondLoc[k][1] - secondLoc[l][1]))
                    else:
                        G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{secondLoc[l][2]}.{secondLoc[l][3]}", weight =abs(secondLoc[k][1] - secondLoc[l][1])) 

    for i in range(len(firstLoc)):
        for k in range(len(secondLoc)):
            if  firstLoc[i][1] >= secondLoc[k][1]:
                 G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{secondLoc[k][2]}.{secondLoc[k][3]}",weight = 80-(firstLoc[i][1] - secondLoc[k][1]))
            else:
                G.add_edge(f"{firstLoc[i][2]}.{firstLoc[i][3]}",f"{secondLoc[k][2]}.{secondLoc[k][3]}",weight = abs(firstLoc[i][1] - secondLoc[k][1]))
    for k in range(len(secondLoc)):
        for i in range(len(firstLoc)):
            if  firstLoc[i][1] < secondLoc[k][1]:
                G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{firstLoc[i][2]}.{firstLoc[i][3]}",weight = 80-(secondLoc[k][1] - firstLoc[i][1]))
            else:
                 G.add_edge(f"{secondLoc[k][2]}.{secondLoc[k][3]}",f"{firstLoc[i][2]}.{firstLoc[i][3]}", weight = abs(firstLoc[i][1] - secondLoc[k][1]))

    return float(nx.algorithms.min_cost_flow_cost(G))
            
def sort_files():
    files = ['P1.txt', 'P2.txt', 'P3.txt', 'P4.txt', 'P5.txt', 'P6.txt', 'P7.txt', 'P8.txt', 'P9.txt', 'P10.txt', 'P11.txt', 'P12.txt', 'P13.txt', 'P14.txt', 'P15.txt']
    #files = ['P1.txt', 'P2.txt', 'P3.txt', 'P4.txt', 'P5.txt', 'P6.txt', 'P7.txt', 'P8.txt', 'P9.txt', 'P11.txt', 'P12.txt', 'P13.txt', 'P14.txt']
    temp = cy.deepcopy(files)
    sorting = [('P1.txt', 1)]
    count = 2
    del temp[0]
    for i in sorting:
        dists = []
        for k in temp:
            if i[0]==k:
                continue
            dists.append((comp_dist(files[files.index(i[0])],files[files.index(k)]),k))   
        #print(dists)
        if len(dists) != 0:
            sorting.append((min(dists)[1],count))
            count += 1
            temp.remove(min(dists)[1])
    sorted_files = list(map(lambda x: x[0], sorting))
    return sorted_files
print(sort_files())
# print(comp_dist("P2.txt","P6.txt"))
# Out:
# ['P1.txt', 'P2.txt', 'P3.txt', 'P10.txt', 'P4.txt', 'P13.txt', 'P14.txt', 'P9.txt', 'P15.txt', 'P7.txt', 'P12.txt', 'P11.txt', 'P5.txt', 'P6.txt', 'P8.txt']
